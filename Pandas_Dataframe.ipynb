# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #CREATING DATAFRAMES

# %%
#using list -- mus tbe 2d
student_data=[
    [100,90,10],
    [90,70,7],
    [120,100,14]
]
pd.DataFrame(student_data,columns=['iq','marks','package'])
# Out:
#     iq  marks  package
# 0  100     90       10
# 1   90     70        7
# 2  120    100       14

# %%
#using dictionary
student_dict={
    'iq':[100,90,120],
    'marks':[90,70,100],
    'package':[10,7,14]
}
students=pd.DataFrame(student_dict)
print(students)
# Out:
#     iq  marks  package
# 0  100     90       10
# 1   90     70        7
# 2  120    100       14

# %%
#using read_csv
movies=pd.read_csv('/content/movies.csv')
print(movies)
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
ipl=pd.read_csv('/content/ipl-matches.csv')
print(ipl)
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %% [markdown]
# #DATAFRAME ATTRIBUTES AND METHODS

# %%
#shape ----rows,cols
print(movies.shape)
print(ipl.shape)
# Out:
# (1629, 18)
# (950, 20)

# %%
#dtype
print(movies.dtypes)
print()
print(ipl.dtypes)
# Out:
# title_x              object
# imdb_id              object
# poster_path          object
# wiki_link            object
# title_y              object
# original_title       object
# is_adult              int64
# year_of_release       int64
# runtime              object
# genres               object
# imdb_rating         float64
# imdb_votes            int64
# story                object
# summary              object
# tagline              object
# actors               object
# wins_nominations     object
# release_date         object
# dtype: object
#
# ID                   int64
# City                object
# Date                object
# Season              object
# MatchNumber         object
# Team1               object
# Team2               object
# Venue               object
# TossWinner          object
# TossDecision        object
# SuperOver           object
# WinningTeam         object
# WonBy               object
# Margin             float64
# method              object
# ...

# %%
#index
print(movies.index)
print(ipl.index)
# Out:
# RangeIndex(start=0, stop=1629, step=1)
# RangeIndex(start=0, stop=950, step=1)

# %%
#columns
print(movies.columns)
print(ipl.columns)
# Out:
# Index(['title_x', 'imdb_id', 'poster_path', 'wiki_link', 'title_y',
#        'original_title', 'is_adult', 'year_of_release', 'runtime', 'genres',
#        'imdb_rating', 'imdb_votes', 'story', 'summary', 'tagline', 'actors',
#        'wins_nominations', 'release_date'],
#       dtype='object')
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
#values --- gives 2 numpy array
students.values
# Out:
# array([[100,  90,  10],
#        [ 90,  70,   7],
#        [120, 100,  14]])

# %%
#head and tail
print(movies.head(5))
print("-------------------")
print(ipl.tail(5))
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %%
#sample--used when there is bias in dataset
print(ipl.sample(5))
# Out:
#           ID        City        Date Season MatchNumber  \
# 475   829739       Delhi  2015-04-20   2015          17
# 764   501208   Hyderabad  2011-04-14   2011          11
# 218  1178411      Jaipur  2019-04-20   2019          36
# 635   548374  Dharamsala  2012-05-19   2012          69
# 417   980931        Pune  2016-04-22   2016          16
#
#                        Team1                        Team2  \
# 475         Delhi Daredevils        Kolkata Knight Riders
# 764          Deccan Chargers  Royal Challengers Bangalore
# 218           Mumbai Indians             Rajasthan Royals
# 635          Kings XI Punjab             Delhi Daredevils
# 417  Rising Pune Supergiants  Royal Challengers Bangalore
#
#                                             Venue  \
# 475                              Feroz Shah Kotla
# 764     Rajiv Gandhi International Stadium, Uppal
# 218                        Sawai Mansingh Stadium
# 635  Himachal Pradesh Cricket Association Stadium
# ...

# %%
#info
print(movies.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1629 entries, 0 to 1628
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           1629 non-null   object
#  1   imdb_id           1629 non-null   object
#  2   poster_path       1526 non-null   object
#  3   wiki_link         1629 non-null   object
#  4   title_y           1629 non-null   object
#  5   original_title    1629 non-null   object
#  6   is_adult          1629 non-null   int64
#  7   year_of_release   1629 non-null   int64
#  8   runtime           1629 non-null   object
#  9   genres            1629 non-null   object
#  10  imdb_rating       1629 non-null   float64
#  11  imdb_votes        1629 non-null   int64
#  12  story             1609 non-null   object
#  13  summary           1629 non-null   object
#  14  tagline           557 non-null    object
#  15  actors            1624 non-null   object
# ...

# %%
#describe--works on numerical columns
print(movies.describe())
# Out:
#        is_adult  year_of_release  imdb_rating     imdb_votes
# count    1629.0      1629.000000  1629.000000    1629.000000
# mean        0.0      2010.263966     5.557459    5384.263352
# std         0.0         5.381542     1.567609   14552.103231
# min         0.0      2001.000000     0.000000       0.000000
# 25%         0.0      2005.000000     4.400000     233.000000
# 50%         0.0      2011.000000     5.600000    1000.000000
# 75%         0.0      2015.000000     6.800000    4287.000000
# max         0.0      2019.000000     9.400000  310481.000000

# %%
#isnull  --- sums true
print(movies.isnull().sum())
# Out:
# title_x                0
# imdb_id                0
# poster_path          103
# wiki_link              0
# title_y                0
# original_title         0
# is_adult               0
# year_of_release        0
# runtime                0
# genres                 0
# imdb_rating            0
# imdb_votes             0
# story                 20
# summary                0
# tagline             1072
# actors                 5
# wins_nominations     922
# release_date         107
# dtype: int64

# %%
#duplicated ---gives number of duplicate rows
print(movies.duplicated().sum())
# Out:
# 0

# %%
#rename function --- rename a column(takes dictionary parameter)
#these changes in not inplace,parameter inplace
print(students)
students.rename(columns={'marks':'percent','package':'lpa'},inplace=True)
# Out:
#     iq  marks  package
# 0  100     90       10
# 1   90     70        7
# 2  120    100       14

# %% [markdown]
# #MATHMATICAL FUNCTIONS

# %%
#sum -arguement(axis)
print(students.sum()) #column wise default
print(students.sum(axis=1)) #row wise sum
# Out:
# iq         310
# percent    260
# lpa         31
# dtype: int64
# 0    200
# 1    167
# 2    234
# dtype: int64

# %%
#mean,median,mode,std,var ---default axis=0 [column]
print(students.mean())
print()
print(students.median())
print()
print(students.mode())
print()
print(students.std())
print()
print(students.var())
# Out:
# iq         103.333333
# percent     86.666667
# lpa         10.333333
# dtype: float64
#
# iq         100.0
# percent     90.0
# lpa         10.0
# dtype: float64
#
#     iq  percent  lpa
# 0   90       70    7
# 1  100       90   10
# 2  120      100   14
#
# iq         15.275252
# percent    15.275252
# lpa         3.511885
# dtype: float64
#
# iq         233.333333
# percent    233.333333
# lpa         12.333333
# dtype: float64

# %% [markdown]
# #SELECTING COLS FROM DF

# %%
#single cols--type series
movies['actors']
# Out:
# 0       Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...
# 1       Vicky Ahuja|Shoaib Ibrahim|Shrikant Kamat|Elen...
# 2       Anupam Kher|Akshaye Khanna|Aahana Kumra|Atul S...
# 3       Emraan Hashmi|Shreya Dhanwanthary|Snighdadeep ...
# 4       Mona Ambegaonkar|Ananth Narayan Mahadevan|Deva...
#                               ...
# 1624    Ajay Devgn|Sonali Bendre|Namrata Shirodkar|Pre...
# 1625    Ameesha Patel|Jimmy Sheirgill|Nafisa Ali|Gulsh...
# 1626    Vijay Arora|Asrani|Rajni Bala|Kumud Damle|Utpa...
# 1627                            Gippy Grewal|Zareen Khan|
# 1628                                          Fawad Khan|
# Name: actors, Length: 1629, dtype: object

# %%
#multiple columns -- using fancy indexing(list of list)--type dataframe
movies[['actors','title_x']]
# Out:
#                                                  actors  \
# 0     Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...
# 1     Vicky Ahuja|Shoaib Ibrahim|Shrikant Kamat|Elen...
# 2     Anupam Kher|Akshaye Khanna|Aahana Kumra|Atul S...
# 3     Emraan Hashmi|Shreya Dhanwanthary|Snighdadeep ...
# 4     Mona Ambegaonkar|Ananth Narayan Mahadevan|Deva...
# ...                                                 ...
# 1624  Ajay Devgn|Sonali Bendre|Namrata Shirodkar|Pre...
# 1625  Ameesha Patel|Jimmy Sheirgill|Nafisa Ali|Gulsh...
# 1626  Vijay Arora|Asrani|Rajni Bala|Kumud Damle|Utpa...
# 1627                          Gippy Grewal|Zareen Khan|
# 1628                                        Fawad Khan|
#
#                                    title_x
# 0                 Uri: The Surgical Strike
# 1                            Battalion 609
# 2     The Accidental Prime Minister (film)
# 3                          Why Cheat India
# 4                          Evening Shadows
# ...

# %% [markdown]
# #FETCHING ROWS

# %%
cs420={
    'name':["a","b","c","d","e"],
    'marks':[2,3,4,6,7],
    'iq':[120,140,70,50,110],
    'lpa':[10,12,14,19,21]
}
cs420_students=pd.DataFrame(cs420)
cs420_students.set_index('name',inplace=True)
print(cs420_students)
# Out:
#       marks   iq  lpa
# name
# a         2  120   10
# b         3  140   12
# c         4   70   14
# d         6   50   19
# e         7  110   21

# %% [markdown]
# ## SELECTING ROWS FROM DATAFRAME

# %% [markdown]
# - iloc -search using index posiition
# - loc -search using index labels

# %%
#search row
print(movies.iloc[0])
# Out:
# title_x                                      Uri: The Surgical Strike
# imdb_id                                                     tt8291224
# poster_path         https://upload.wikimedia.org/wikipedia/en/thum...
# wiki_link           https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# title_y                                      Uri: The Surgical Strike
# original_title                               Uri: The Surgical Strike
# is_adult                                                            0
# year_of_release                                                  2019
# runtime                                                           138
# genres                                               Action|Drama|War
# imdb_rating                                                       8.4
# imdb_votes                                                      35112
# story               Divided over five chapters  the film chronicle...
# ...

# %%
#multiple rows
print(movies.iloc[1:5:2])
# Out:
#            title_x    imdb_id  \
# 1    Battalion 609  tt9472208
# 3  Why Cheat India  tt8108208
#
#                                          poster_path  \
# 1                                                NaN
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                        wiki_link          title_y  \
# 1    https://en.wikipedia.org/wiki/Battalion_609    Battalion 609
# 3  https://en.wikipedia.org/wiki/Why_Cheat_India  Why Cheat India
#
#     original_title  is_adult  year_of_release runtime       genres  \
# 1    Battalion 609         0             2019     131          War
# 3  Why Cheat India         0             2019     121  Crime|Drama
#
#    imdb_rating  imdb_votes                                              story  \
# 1          4.1          73  The story revolves around a cricket match betw...
# 3          6.0        1891  The movie focuses on existing malpractices in ...
#
# ...

# %%
#fancy indexing
print(movies.iloc[[0,4,5]])
# Out:
#                     title_x    imdb_id  \
# 0  Uri: The Surgical Strike  tt8291224
# 4           Evening Shadows  tt6028796
# 5               Soni (film)  tt6078866
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
# 5  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
# 5          https://en.wikipedia.org/wiki/Soni_(film)
#
#                     title_y            original_title  is_adult  \
# 0  Uri: The Surgical Strike  Uri: The Surgical Strike         0
# 4           Evening Shadows           Evening Shadows         0
# 5                      Soni                      Soni         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# ...

# %%
#loc
print(cs420_students.loc['a'])
print(cs420_students.iloc[0])
# Out:
# marks      2
# iq       120
# lpa       10
# Name: a, dtype: int64
# marks      2
# iq       120
# lpa       10
# Name: a, dtype: int64

# %%
cs420_students.loc['a':'c'] #both included
# Out:
#       marks   iq  lpa
# name
# a         2  120   10
# b         3  140   12
# c         4   70   14

# %% [markdown]
# #SELECTING BOTH ROWS AND COLS

# %%
movies.iloc[0:3,0:3] #provide index
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...

# %%
movies.loc[0:2,'title_x':'poster_path'] #provide labels
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...

# %%
#find all the final winners
mask=ipl['MatchNumber']=='Final'
newdf=ipl[mask]
newdf[['Season','WinningTeam']]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %%
#how manu superover finishes have occured
sum(ipl['SuperOver']=='Y')
# Out:
# 14

# %%
#toss winner is match winner in percentage
sum(ipl['TossWinner']==ipl['WinningTeam'])*100/ipl.shape[0]
# Out:
# 51.473684210526315

# %%
#how many matches has csk won in kolkata
print(ipl['City']=='Kolkata')
print("------------------------")
print(ipl[ipl['City']=='Kolkata']) #rows with only city kolkata
print("------------------------")
ipl[(ipl['City']=='Kolkata') &  (ipl['WinningTeam']=='Chennai Super Kings')]
# Out:
# 0      False
# 1      False
# 2       True
# 3       True
# 4      False
#        ...
# 945     True
# 946    False
# 947    False
# 948    False
# 949    False
# Name: City, Length: 950, dtype: bool
# ------------------------
#           ID     City        Date   Season  MatchNumber  \
# 2    1312198  Kolkata  2022-05-25     2022   Eliminator
# 3    1312197  Kolkata  2022-05-24     2022  Qualifier 1
# 207  1178422  Kolkata  2019-04-28     2019           47
# 211  1178418  Kolkata  2019-04-25     2019           43
# 219  1178410  Kolkata  2019-04-19     2019           35
# ..       ...      ...         ...      ...          ...
# 908   336025  Kolkata  2008-05-18  2007/08           41
# 915   336017  Kolkata  2008-05-13  2007/08           35
# 922   336010  Kolkata  2008-05-08  2007/08           29
# 934   335997  Kolkata  2008-04-29  2007/08           16
# 945   335986  Kolkata  2008-04-20  2007/08            4
#
#                            Team1                        Team2  \
# ...

# %%
#movies with rating higher than 8 and votes>10000
print((movies['imdb_rating']>8) & (movies['imdb_votes']>10000))
print(movies[(movies['imdb_rating']>8) & (movies['imdb_votes']>10000)].shape[0])
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1624    False
# 1625    False
# 1626    False
# 1627    False
# 1628    False
# Length: 1629, dtype: bool
# 43

# %%
#write a function that can return record of 2 teams against each other

# %% [markdown]
# #ADDING NEW COLUMN

# %%
#completely new column
movies['country']='India'
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
#from existing column

# %% [markdown]
# #IMPORTANT METHODS

# %%
dict={
    'name':['a','b','c','a'],
    'class':[2,3,4,2],
    'percent':[3,4,5,3]
}
stu=pd.DataFrame(dict)
print(stu)
# Out:
#   name  class  percent
# 0    a      2        3
# 1    b      3        4
# 2    c      4        5
# 3    a      2        3

# %%
#clip method
# movies['runtime'].clip(100,200) #provide movies only which have runtime between 100 and 200 minutes
#if value will be less than 100 , it will become 100 and if greater than 200 , it will become 200
stu['percent'].clip(3,4)
print(stu)
# Out:
#   name  class  percent
# 0    a      2        3
# 1    b      3        4
# 2    c      4        5
# 3    a      2        3

# %%
#drop duplicates --- parameter (keep='last'/''first')--by default first
stu.drop_duplicates()
# Out:
#   name  class  percent
# 0    a      2        3
# 1    b      3        4
# 2    c      4        5

# %%
#duplicated -- returns boolean series
movies.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1624    False
# 1625    False
# 1626    False
# 1627    False
# 1628    False
# Length: 1629, dtype: bool

# %%
#isnull
temp=pd.Series([1,2,3,np.nan,5,6,np.nan,8,np.nan,10])
print(temp)
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 3     NaN
# 4     5.0
# 5     6.0
# 6     NaN
# 7     8.0
# 8     NaN
# 9    10.0
# dtype: float64

# %%
print(temp.size) #counts null values as well
print(temp.count()) #counts non-null values only
# Out:
# 10
# 7

# %%
#isnull --- works on series
temp.isnull().sum()
# Out:
# 3

# %% [markdown]
# #HANDLING NULL VALUES/

# %%
#dropna --- drop all null values
temp.dropna()
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 4     5.0
# 5     6.0
# 7     8.0
# 9    10.0
# dtype: float64

# %%
#fillna --- by any value temp.mean()/temp.median
temp.fillna(0)
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 3     0.0
# 4     5.0
# 5     6.0
# 6     0.0
# 7     8.0
# 8     0.0
# 9    10.0
# dtype: float64

# %%
#apply --very useful
# movies.apply(lambda x:x.split()) ---kind of for loop

# %%
#copy and view --- when we do head or tail, it does not make copy actually it just creates a view
newtemp=temp.head(1)
print(newtemp)
print("----------------")
print(temp.head(1))
newtemp[0]=5
print(temp.head(1))
# Out:
# 0    5.0
# dtype: float64
# ----------------
# 0    5.0
# dtype: float64
# 0    5.0
# dtype: float64

# %%
tempcopy=temp.head().copy()
